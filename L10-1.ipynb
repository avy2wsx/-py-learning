# %%
import json
with open('F-C0032-001.json',encoding='utf-8') as file:
    json_str = file.read()
    weather = json.loads(json_str)

# %%
location = weather ['cwopendata']['dataset']['location']
for item in location:
    print(item)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 location = weather ['cwopendata']['dataset']['location']
#       2 for item in location:
#       3     print(item)
#
# KeyError: 'cwopendata'

# %%
import requests
url = 'https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON'

response = requests.get(url)
if response.status_code ==200:
    print("下載成功")
    weather =response.json()
# Out:
# 下載成功

# %%
location = weather['cwbopendata']['dataset']['location']
weather_list = []
for item in location:
    city_item = {}
    city_item['城市'] = item['locationName']
    city_item['起始時間'] = item['weatherElement'][1]['time'][0]['startTime']
    city_item['結束時間'] = item['weatherElement'][1]['time'][0]['endTime']
    city_item['最高溫度'] = float(item['weatherElement'][1]['time'][0]['parameter']['parameterName'])
    city_item['最低溫度'] = float(item['weatherElement'][2]['time'][0]['parameter']['parameterName'])
    city_item['感覺'] = item['weatherElement'][3]['time'][0]['parameter']['parameterName']
    weather_list.append(city_item)
weather_list
# Out:
# [{'城市': '臺北市',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 35.0,
#   '最低溫度': 32.0,
#   '感覺': '悶熱'},
#  {'城市': '新北市',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 31.0,
#   '感覺': '悶熱'},
#  {'城市': '桃園市',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 35.0,
#   '最低溫度': 32.0,
#   '感覺': '悶熱至易中暑'},
#  {'城市': '臺中市',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 35.0,
#   '最低溫度': 32.0,
#   '感覺': '悶熱'},
#  {'城市': '臺南市',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 33.0,
#   '最低溫度': 31.0,
#   '感覺': '悶熱'},
#  {'城市': '高雄市',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 33.0,
#   '最低溫度': 31.0,
#   '感覺': '悶熱'},
#  {'城市': '基隆市',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 31.0,
#   '感覺': '悶熱'},
#  {'城市': '新竹縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 31.0,
#   '感覺': '悶熱'},
#  {'城市': '新竹市',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 33.0,
#   '最低溫度': 31.0,
#   '感覺': '悶熱'},
#  {'城市': '苗栗縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 31.0,
#   '感覺': '悶熱至易中暑'},
#  {'城市': '彰化縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 32.0,
#   '感覺': '悶熱'},
#  {'城市': '南投縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 31.0,
#   '感覺': '悶熱至易中暑'},
#  {'城市': '雲林縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 30.0,
#   '感覺': '悶熱至易中暑'},
#  {'城市': '嘉義縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 31.0,
#   '感覺': '悶熱至易中暑'},
#  {'城市': '嘉義市',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 35.0,
#   '最低溫度': 30.0,
#   '感覺': '悶熱至易中暑'},
#  {'城市': '屏東縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 34.0,
#   '最低溫度': 31.0,
#   '感覺': '悶熱'},
#  {'城市': '宜蘭縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 33.0,
#   '最低溫度': 30.0,
#   '感覺': '悶熱'},
#  {'城市': '花蓮縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 32.0,
#   '最低溫度': 30.0,
#   '感覺': '悶熱'},
#  {'城市': '臺東縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 32.0,
#   '最低溫度': 30.0,
#   '感覺': '悶熱'},
#  {'城市': '澎湖縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 33.0,
#   '最低溫度': 30.0,
#   '感覺': '悶熱'},
#  {'城市': '金門縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 33.0,
#   '最低溫度': 30.0,
#   '感覺': '悶熱至易中暑'},
#  {'城市': '連江縣',
#   '起始時間': '2023-07-22T12:00:00+08:00',
#   '結束時間': '2023-07-22T18:00:00+08:00',
#   '最高溫度': 32.0,
#   '最低溫度': 29.0,
#   '感覺': '悶熱'}]
